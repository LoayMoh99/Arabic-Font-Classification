# %%
print('Arabic Font Classification Project!!')
# Out:
# Arabic Font Classification Project!!

# %% [markdown]
# # Classification Methods
# In this lab, it is required to identify between different hand-drawn shapes; such as rectangles, circles, triangles, ellipses, polygons, etc.
#
# We will start our first lab in this course by understanding the main pipeline of any machine learning project:
#
# **Important Note:** **Read all the code and fill the required functions in the 'utils' notebook as you go.**

# %%
#Always make all imports in the first cell of the notebook, run them all once.
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from skimage.filters import threshold_otsu
from __future__ import division
import numpy as np
from scipy.signal import convolve2d
from sklearn import svm ,metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import random
from sklearn.utils import shuffle

# for NN:
import keras
from keras.models import Sequential
from keras.layers import Dense


# %matplotlib inline

# %% [markdown]
# # A Machine Learning (ML) project is divided into many stages:
#
# ## 1. Gathering Data (Data Acquisition):
#
# The first real step of machine learning is gathering data. This step is very important because the **quality and quantity** of data that you gather will directly determine how good your predictive model can be.

# %% [markdown]
# We define placeholders for the data as follows:
# * **x_train:** This represents the images in the training set.
# * **y_train:** This represents the labels of the images in the training set.

# %%
x_train = []
y_train = []
x_test = []
y_test = []
styles = []

# %%
# load styles names:
with open('ACdata_base/names.txt') as file:
    lines = file.readlines()
    styles = [line.rstrip()[4:] for line in lines] # ignoring number at first of each style (first 4 chars)
print(styles)
# Out:
# ['diwani', 'naskh', 'parsi', 'rekaa', 'thuluth', 'maghribi', 'kufi', 'mohakek', 'Squar-kufic']

# %%
## load styles images:
x=[]
y=[]
for i in range(1, len(styles)+1):
    for filename in sorted(glob.glob('ACdata_base/'+str(i)+'/*.jpg')):
        img = cv2.imread(filename) ## cv2.imread reads images in RGB format
        x_train.append(img)
        y_train.append(i-1)
        # x.append(img)
        # y.append(i-1)

# for i in range(1, len(styles)+1):
#     for filename in sorted(glob.glob('ACdata_base_test/'+str(i)+'/*.jpg')):
#         img = cv2.imread(filename) ## cv2.imread reads images in RGB format
#         x_test.append(img)
#         y_test.append(i-1)

# %%
# A good practice is to convert lists into numpy arrays. When it comes to actual machine learning algorithms, 
# it is better to work with NumPy arrays.
x_train = np.asarray(x_train)
y_train = np.asarray(y_train)
#x_train = x_train.reshape(-1,1)
#y_train = y_train.reshape(-1,1)

print ("The size of the training set is: ", x_train.shape)

# We have a lot of images of different arabic styles, where each image is an RGB image of dimensions 200x200x3. 
# (images, height, width, channels)

print ("The size of the labels of the training set is: ", y_train.shape)
print (y_train)
# Out:
# The size of the training set is:  (1685,)
# The size of the labels of the training set is:  (1685,)
# [0 0 0 ... 8 8 8]
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# We will now visualize this dataset.
#
# **Note: You can run the following cell multiple times to view different shapes in the dataset as well as the ground-truth value associated with this training image.**

# %%
# Generate a random index from 0 to 18 inclusive. 
random_index = np.random.randint(0,18)

# Plot the image.
plt.imshow(x_train[random_index])
plt.axis("off")

print("The ground-truth value of this image is: " , styles[y_train[random_index]])
# Out:
# The ground-truth value of this image is:  diwani

# %% [markdown]
# - - -
# # 2. Data Preprocessing:
#
# The second stage is to convert the raw data into a clean data set. In other words, whenever the data is gathered from different sources it is collected in raw format which is not feasible for the analysis. We need to prepare it to be suitable for our problem.
#
# In this step, we will apply preprocessing to the images in **x_train** as follows:
#    1. Convert RGB images to grayscale images. Use the function **cv2.cvtColor**
#    2. Remove noise in images by blurring (averaging). Use the function **cv2.blur**
#    3. Applying a binary threshold on the image pixels. Use the function **cv2.threshold**. The pixels having intensity less than this threshold should be considered black pixels, and white otherwise.

# %%
def preprocess(img):
    # Preprocess the given image img.
    #-----------------------------------------------------------------------------------------------
    # Convert the image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    #-----------------------------------------------------------------------------------------------
    #Convert the grayscale image to a binary image. Apply a threshold using Otsu's method on the blurred image.
    # get the threshold of the image using Otsu's method
    thresh = threshold_otsu(gray)
    thresholded_img = gray > thresh
    #_, thresholded_img = cv2.threshold(gray, 0, 1, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
    #-----------------------------------------------------------------------------------------------
    return thresholded_img

# %%
# We will apply the function you implemented for each image in the training set (x_train) 
# and add the pre-processed images to a new list (x_train_preprocessed.)
x_train_preprocessed = []
for i in range(x_train.shape[0]):
    preprocessed_img = preprocess(x_train[i])
    x_train_preprocessed.append(preprocessed_img)

# %%
x_train_preprocessed = np.asarray(x_train_preprocessed)

shape = x_train_preprocessed.shape

# %%
# Let's visualize what happened after preprocessing 

# Generate a random index from 0 to 18 inclusive. 
random_index = np.random.randint(0,18)

# Plot the image before preprocessing.
plt.imshow(x_train[random_index],cmap='gray')
plt.axis("off")
plt.title("Before Preprocessing")
plt.show()

# Plot the image after preprocessing.
plt.imshow(x_train_preprocessed[random_index],cmap='gray')
plt.axis("off")
plt.title("After Preprocessing")
plt.show()

# %%
# We do not need the original x_train anymore. We will work on x_train_preprocessed from now on. 
x_train = x_train_preprocessed

# %% [markdown]
# - - -
# # 3. Feature Extraction:
#
# Now that we have clean and preprocessed data, we can use it to solve our classification problem.
#
# This step could be either:
#
# * **Feature Engineering:** transformation of raw data into features suitable for modeling.
#
# * **Feature Transformation:** transformation of data to improve the accuracy of the algorithm.
#
# * **Feature Selection:** removing unnecessary features.
#
# The process of feature extraction in our problem can have many designs:
#
# * One design is to extract the number of black pixels compared to the number of white pixels in each image and use this feature to differentiate between different shapes. (Is this a powerful feature?) Can you think of other features?
#
#
# A more powerful set of features can be obtained by computing the convex hull of these shapes, and compare the area of this convex hull with the minimum enclosing circle, minimum enclosing rectangle and minimum enclosing triangle bounding that figure.
#
#
# In the example above, the ratio between the areas of the convex hull (traingular figure) to the area of the bounding triangle will be maximum, and relatively smaller for the bounding rectangle and circle respectively.
#
# On the other hand, if the given shape was a circle, then the ratio between the areas of the shape to the bounding circle will be maximum and smaller for the bounding rectangle and triangle.
#
# Therefore, each image will be represented with a feature vector in three dimensions **(x, y and z)** where each component represents the ratio between the area of the figure to the area of the bounding rectangle, circle and triangle respectively.
#
# **The images in the example above can be represented as a feature vector (0.67, 0.58, 0.92)**
#
# We will now implement all functions needed for feature extraction.

# %%
# LPQ "Local Phase Quantization" Feature Extraction:
def lpq(img,winSize=5,freqestim=1,mode='nh'):
    rho=0.90

    STFTalpha=1/winSize  # alpha in STFT approaches (for Gaussian derivative alpha=1)
    sigmaS=(winSize-1)/4 # Sigma for STFT Gaussian window (applied if freqestim==2)
    sigmaA=8/(winSize-1) # Sigma for Gaussian derivative quadrature filters (applied if freqestim==3)

    convmode='valid' # Compute descriptor responses only on part that have full neigborhood. Use 'same' if all pixels are included (extrapolates np.image with zeros).

    img=np.float64(img) # Convert np.image to double
    r=(winSize-1)/2 # Get radius from window size
    x=np.arange(-r,r+1)[np.newaxis] # Form spatial coordinates in window

    if freqestim==1:  #  STFT uniform window
        #  Basic STFT filters
        w0=np.ones_like(x)
        w1=np.exp(-2*np.pi*x*STFTalpha*1j)
        w2=np.conj(w1)

    ## Run filters to compute the frequency response in the four points. Store np.real and np.imaginary parts separately
    # Run first filter
    filterResp1=convolve2d(convolve2d(img,w0.T,convmode),w1,convmode)
    filterResp2=convolve2d(convolve2d(img,w1.T,convmode),w0,convmode)
    filterResp3=convolve2d(convolve2d(img,w1.T,convmode),w1,convmode)
    filterResp4=convolve2d(convolve2d(img,w1.T,convmode),w2,convmode)

    # Initilize frequency domain matrix for four frequency coordinates (np.real and np.imaginary parts for each frequency).
    freqResp=np.dstack([filterResp1.real, filterResp1.imag,
                        filterResp2.real, filterResp2.imag,
                        filterResp3.real, filterResp3.imag,
                        filterResp4.real, filterResp4.imag])

    ## Perform quantization and compute LPQ codewords
    inds = np.arange(freqResp.shape[2])[np.newaxis,np.newaxis,:]
    LPQdesc=((freqResp>0)*(2**inds)).sum(2)

    ## Switch format to uint8 if LPQ code np.image is required as output
    if mode=='im':
        LPQdesc=np.uint8(LPQdesc)

    ## Histogram if needed
    if mode=='nh' or mode=='h':
        LPQdesc=np.histogram(LPQdesc.flatten(),range(256))[0]

    ## Normalize histogram if needed
    if mode=='nh':
        LPQdesc=LPQdesc/LPQdesc.sum()

    #print(LPQdesc)
    return LPQdesc

# %% [markdown]
# We finally populate the array **training_features** with the extracted features from each image using the functions you implemented earlier.

# %% [markdown]
# ## Visualize the Features
# A very useful step here is to visualize your features, see how they separate different classes from one another, and how they group data points from the same class closer together.

# %%
features = [lpq(x,winSize=5) for x in x_train]
features= np.array(features)

# %% [markdown]
# - - -
# # 4. ML Model:
# It’s time to feed the crafted features to the classification algorithm that is going to classify or predict the class of unknown or newly unseen data (called testing data). The process of choosing which classification algorithm will yield the best results is not an easy one. It is often subject to many iterations of tuning parameters and features.
#
# In this lab, we will apply three classification algorithms and compare their results:
# 1. **SVM.**
# 2. **Radnom Forest.**
# 3. **K-Nearest Neighbour Classifier.**
# 3. **Neural Network as a Classifier.**

# %%
#SVM CLASSIFIER

# average setting, one of [None, 'micro', 'macro', 'weighted'].
def svmCLF(feats,y_lbl,test_x,test_y):
    clf = svm.SVC(kernel='poly',degree=2,C=500)
    print(feats.shape)
    clf.fit(feats, y_lbl)
    y_preds = clf.predict(test_x)
        
    ascore = metrics.accuracy_score(test_y, y_preds)
    pscore = metrics.precision_score(test_y, y_preds,average='weighted')
    rscore = metrics.recall_score(test_y, y_preds,average='weighted')
    fscore = metrics.f1_score(test_y, y_preds,average='weighted')
    print("Accuracy:",round(ascore*100,2) ,'%')
    print("Precision:",round(pscore*100,2),'%')
    print("Recall:",round(rscore*100,2),'%')
    print("f1 score:",round(fscore*100,2),'%')

    return ascore,pscore,rscore,fscore
#svmCLF(features,y_train,x_test,y_test)

# %%
# KNN CLASSIFIER
def KNNCLF(feats,y_lbl,test_x,test_y):

    clf = KNeighborsClassifier(n_neighbors=1)
    clf.fit(feats, y_lbl)
    y_predk = clf.predict(test_x)
    ascore = metrics.accuracy_score(test_y, y_predk)
    pscore = metrics.precision_score(test_y, y_predk,average='weighted')
    rscore = metrics.recall_score(test_y, y_predk,average='weighted')
    fscore = metrics.f1_score(test_y, y_predk,average='weighted')
    
    print("Accuracy:",round(ascore*100,2) ,'%')
    print("Precision:",round(pscore*100,2),'%')
    print("Recall:",round(rscore*100,2),'%')
    print("f1 score:",round(fscore*100,2),'%')

    return ascore,pscore,rscore,fscore
# KNNCLF(features,y_train,x_test,y_test)

# %%
# Random Forest Tree CLASSIFIER

# average setting, one of [None, 'micro', 'macro', 'weighted'].
def RFCLF(feats,y_lbl,test_x,test_y):
    clf = RandomForestClassifier(max_depth=13, random_state=3,n_estimators=500)
    print(feats.shape)
    clf.fit(feats, y_lbl)
    y_predr = clf.predict(test_x)
    ascore = metrics.accuracy_score(test_y, y_predr)
    pscore = metrics.precision_score(test_y, y_predr,average='weighted')
    rscore = metrics.recall_score(test_y, y_predr,average='weighted')
    fscore = metrics.f1_score(test_y, y_predr,average='weighted')

    print("Accuracy:",round(ascore*100,2) ,'%')
    print("Precision:",round(pscore*100,2),'%')
    print("Recall:",round(rscore*100,2),'%')
    print("f1 score:",round(fscore*100,2),'%')

    return ascore,pscore,rscore,fscore

# RFCLF(features,y_train,x_test,y_test)

# %%
# Neural network as a Classifier:

def NeuralCLF(feats,y_lbl,test_x,test_y):
    model = Sequential()
    model.add(Dense(16, input_dim=len(feats[0]), activation='relu'))
    model.add(Dense(12, activation='relu'))
    model.add(Dense(9, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    y_lbl=np.asarray(y_lbl).astype(np.float32)
    feats = np.asarray(feats).astype(np.float32)
    history = model.fit(feats, y_lbl, epochs=1000, batch_size=255)

    y_prednn = model.predict(test_x)
    y_prednn_labels = np.argmax(y_prednn,axis=1)
    ascore = metrics.accuracy_score(test_y, y_prednn_labels)
    pscore = metrics.precision_score(test_y, y_prednn_labels,average='weighted')
    rscore = metrics.recall_score(test_y, y_prednn_labels,average='weighted')
    fscore = metrics.f1_score(test_y, y_prednn_labels,average='weighted')

    print("Accuracy:",round(ascore*100,2) ,'%')
    print("Precision:",round(pscore*100,2),'%')
    print("Recall:",round(rscore*100,2),'%')
    print("f1 score:",round(fscore*100,2),'%')

    return ascore,pscore,rscore,fscore

# %% [markdown]
# - - -
# # 5. Cross Validation:
# We will use K-fold for cross validation since our data is limited
# divindg our data in to k arrays
# Training k-1 arrays
# Testing on 1 array
#
# Repeat k permutations on our data set
#
# ### Computing Means:
# We check for each classifiers' `mean` to check for the best accuracies
# classfieirs:
# -   SVM
# -   RF
# -   KNN
# -   Neural Network

# %%
# Our k-fold returns batches of random folds
def KFold(K,x_train,y_train,seed=0):
    fold_size = round(len(x_train)/K)
    
    x_fold = []# np.zeros((fold_size,1))
    y_fold = []#np.zeros((fold_size,1))
    #random.shuffle(x_train)
    
    x_shuff, y_shuff = shuffle(x_train, y_train, random_state=seed)

    for j in range(K): #10 times
        tempx = []
        tempy = []
        for i in range(j*fold_size,fold_size*(j+1)):
            tempx.append(x_shuff[i])
            tempy.append(y_shuff[i])
        y_fold.append(tempy)
        x_fold.append(tempx)
        print(len(tempx))

        
    # y_fold = np.array(y_fold)
    # x_fold = np.array(x_fold)

    return x_fold,y_fold

# xf,yf = KFold(10,x,y)
# print(xf.shape)


    #random.shuffle(array)

# %%
x_fold,y_fold = KFold(10,features,y_train,2)

x_train_f=[]
y_train_f=[]
y_train_nn_f=[]
x_test =[]
y_test = []
for index,_ in enumerate(x_fold): #assiging 10[168]
    if(i==index):
        x_test = x_fold[index]
        y_test = y_fold[index]
    else:
        x_train_f.extend(x_fold[index])
        y_train_f.extend(y_fold[index])
#convert y_train to y_train_nn for NN
for fold_ele in y_train_f:
    ynn = np.zeros(len(styles),dtype='float32')
    ynn[fold_ele] = 1.0
    y_train_nn_f.append(ynn)
x_train_f=np.array(x_train_f)
y_train_f=np.array(y_train_f)
y_train_nn_f=np.array(y_train_nn_f)
x_test = np.array(x_test)
y_test = np.array(y_test)

print(y_train_f.shape)
print(y_train_nn_f.shape)
#NN_score,pn,rn,fn = NeuralCLF(x_train_f,y_train_nn_f,x_test,y_test)
# Out:
# 168
# 168
# 168
# 168
# 168
# 168
# 168
# 168
# 168
# 168
# (1680,)
# (1680, 9)

# %%
# x and y passed by k-fold 10 since it's recommended
# Trying it out on svm first
## svm-> x_fold 0-8 x_test=x_fold[9]
def Kprocessing(k,x_fold,y_fold):
    svm_Scores=[]
    KNN_scores=[]
    RF_scores= []
    NN_scores= []
    for i in range(k): #loop 10 times
        x_train_f=[]
        y_train_f=[]
        y_train_nn_f=[]
        x_test =[]
        y_test = []
        for index,_ in enumerate(x_fold): #assiging 10[168]
            if(i==index):
                x_test = x_fold[index]
                y_test = y_fold[index]
            else:
                x_train_f.extend(x_fold[index])
                y_train_f.extend(y_fold[index])
        #convert y_train to y_train_nn for NN
        for fold_ele in y_train_f:
            ynn = np.zeros(len(styles),dtype='float32')
            ynn[fold_ele] = 1.0
            y_train_nn_f.append(ynn)
        x_train_f=np.array(x_train_f)
        y_train_f=np.array(y_train_f)
        y_train_nn_f=np.array(y_train_nn_f)
        x_test = np.array(x_test)
        y_test = np.array(y_test)

        # Get scores for each classifiers aprf
        svm_score,ps,rs,fs = svmCLF(x_train_f,y_train_f,x_test,y_test)
        KNN_score,pk,rk,fk = KNNCLF(x_train_f,y_train_f,x_test,y_test)
        RF_score,pr,rr,fr = RFCLF(x_train_f,y_train_f,x_test,y_test)
        NN_score,pn,rn,fn = NeuralCLF(x_train_f,y_train_nn_f,x_test,y_test)

        # appending scores
        svm_Scores.append([svm_score,ps,rs,fs])
        KNN_scores.append([KNN_score,pk,rk,fk])
        RF_scores.append([RF_score,pr,rr,fr])
        NN_scores.append([NN_score,pn,rn,fn])
        
    # converting to np arrays
    svm_Scores=np.array(svm_Scores)
    KNN_scores=np.array(KNN_scores)
    RF_scores=np.array(RF_scores)
    NN_scores=np.array(NN_scores)

    # computing mean accuracies
    svm_meana = np.mean(svm_Scores[:,0])
    KNN_meana = np.mean(KNN_scores[:,0])
    RF_meana = np.mean(RF_scores[:,0])
    NN_meana = np.mean(NN_scores[:,0])

    # computing mean precision
    svm_meanp = np.mean(svm_Scores[:,1])
    KNN_meanp = np.mean(KNN_scores[:,1])
    RF_meanp = np.mean(RF_scores[:,1])
    NN_meanp = np.mean(NN_scores[:,1])
    
    # computing mean recall
    svm_meanr = np.mean(svm_Scores[:,2])
    KNN_meanr = np.mean(KNN_scores[:,2])
    RF_meanr = np.mean(RF_scores[:,2])
    NN_meanr = np.mean(NN_scores[:,2])

    # computing mean F1
    svm_meanf = np.mean(svm_Scores[:,3])
    KNN_meanf = np.mean(KNN_scores[:,3])
    RF_meanf = np.mean(RF_scores[:,3])
    NN_meanf = np.mean(NN_scores[:,3])

    #appending each score means for each clf
    svm_Real_score = [svm_meana,svm_meanp,svm_meanr,svm_meanf]
    KNN_Real_score = [KNN_meana,KNN_meanp,KNN_meanr,KNN_meanf]
    RF_Real_score = [RF_meana,RF_meanp,RF_meanr,RF_meanf]
    NN_Real_score = [NN_meana,NN_meanp,NN_meanr,NN_meanf]

    return(svm_Real_score,KNN_Real_score,RF_Real_score,NN_Real_score)

# %%
# Proccessing the K-fold
x_fold,y_fold = KFold(10,features,y_train,2)
svm_real_score,knn_real_score,rf_real_score,nn_real_score = Kprocessing(10,x_fold,y_fold)
# Out:
# 168
# 168
# 168
# 168
# 168
# 168
# 168
# 168
# 168
# 168
# (1512, 255)
# Accuracy: 98.21 %
# Precision: 98.35 %
# Recall: 98.21 %
# f1 score: 98.23 %
# Accuracy: 83.93 %
# Precision: 84.56 %
# Recall: 83.93 %
# f1 score: 83.83 %
# (1512, 255)
# Accuracy: 99.4 %
# Precision: 99.44 %
# Recall: 99.4 %
# f1 score: 99.41 %
# Epoch 1/1000
# 6/6 [==============================] - 1s 7ms/step - loss: 2.1978 - accuracy: 0.1104
# Epoch 2/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 2.1944 - accuracy: 0.1733
# Epoch 3/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.1912 - accuracy: 0.2209
# Epoch 4/1000
# 6/6 [==============================] - ETA: 0s - loss: 2.1897 - accuracy: 0.22 - 0s 7ms/step - loss: 2.1884 - accuracy: 0.2302
# Epoch 5/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.1860 - accuracy: 0.2870
# Epoch 6/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.1831 - accuracy: 0.2851
# Epoch 7/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1800 - accuracy: 0.2864
# Epoch 8/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.1768 - accuracy: 0.2798
# Epoch 9/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1729 - accuracy: 0.2500
# Epoch 10/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.1684 - accuracy: 0.2553
# Epoch 11/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.1635 - accuracy: 0.2751
# Epoch 12/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1575 - accuracy: 0.2745
# Epoch 13/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1502 - accuracy: 0.2652
# Epoch 14/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.1424 - accuracy: 0.2487
# Epoch 15/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1334 - accuracy: 0.2341
# Epoch 16/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1232 - accuracy: 0.2335
# Epoch 17/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1122 - accuracy: 0.2354
# Epoch 18/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.0999 - accuracy: 0.2302
# Epoch 19/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 2.0862 - accuracy: 0.2269
# Epoch 20/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.0712 - accuracy: 0.2269
# Epoch 21/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.0552 - accuracy: 0.2269
# Epoch 22/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 2.0384 - accuracy: 0.2282
# Epoch 23/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.0200 - accuracy: 0.2295
# Epoch 24/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.0013 - accuracy: 0.2315
# Epoch 25/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.9820 - accuracy: 0.2321
# Epoch 26/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.9626 - accuracy: 0.2348
# Epoch 27/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.9428 - accuracy: 0.2368
# Epoch 28/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.9232 - accuracy: 0.2394
# Epoch 29/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.9039 - accuracy: 0.2434
# Epoch 30/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.8853 - accuracy: 0.2493
# Epoch 31/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.8672 - accuracy: 0.2507
# Epoch 32/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.8499 - accuracy: 0.2573
# Epoch 33/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.8337 - accuracy: 0.2619
# Epoch 34/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.8177 - accuracy: 0.2731
# Epoch 35/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.8026 - accuracy: 0.3452
# Epoch 36/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.7883 - accuracy: 0.3717
# Epoch 37/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.7742 - accuracy: 0.3485
# Epoch 38/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.7609 - accuracy: 0.3373
# Epoch 39/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.7480 - accuracy: 0.3459
# Epoch 40/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.7356 - accuracy: 0.3433
# Epoch 41/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.7234 - accuracy: 0.3492
# Epoch 42/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.7116 - accuracy: 0.3532
# Epoch 43/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.7001 - accuracy: 0.3763
# Epoch 44/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 1.6889 - accuracy: 0.3935
# Epoch 45/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.6779 - accuracy: 0.4101
# Epoch 46/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.6668 - accuracy: 0.4253
# Epoch 47/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.6563 - accuracy: 0.4610
# Epoch 48/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 1.6453 - accuracy: 0.4808
# Epoch 49/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.6345 - accuracy: 0.4921
# Epoch 50/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.6237 - accuracy: 0.5066
# Epoch 51/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 1.6128 - accuracy: 0.5159
# Epoch 52/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.6019 - accuracy: 0.5245
# Epoch 53/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.5909 - accuracy: 0.5331
# Epoch 54/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5797 - accuracy: 0.5430
# Epoch 55/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.5682 - accuracy: 0.5503
# Epoch 56/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.5569 - accuracy: 0.5575
# Epoch 57/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.5450 - accuracy: 0.5595
# Epoch 58/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.5332 - accuracy: 0.5595
# Epoch 59/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5216 - accuracy: 0.5615
# Epoch 60/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.5095 - accuracy: 0.5648
# Epoch 61/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.4975 - accuracy: 0.5668
# Epoch 62/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4855 - accuracy: 0.5648
# Epoch 63/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.4731 - accuracy: 0.5675
# Epoch 64/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4609 - accuracy: 0.5734
# Epoch 65/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4489 - accuracy: 0.5741
# Epoch 66/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.4369 - accuracy: 0.5728
# Epoch 67/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.4249 - accuracy: 0.5701
# Epoch 68/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4131 - accuracy: 0.5767
# Epoch 69/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4018 - accuracy: 0.5787
# Epoch 70/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.3898 - accuracy: 0.5767
# Epoch 71/1000
# 6/6 [==============================] - ETA: 0s - loss: 1.4183 - accuracy: 0.52 - 0s 9ms/step - loss: 1.3782 - accuracy: 0.5807
# Epoch 72/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 1.3672 - accuracy: 0.5800
# Epoch 73/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.3558 - accuracy: 0.5807
# Epoch 74/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.3452 - accuracy: 0.5866
# Epoch 75/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.3346 - accuracy: 0.5899
# Epoch 76/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.3242 - accuracy: 0.5926
# Epoch 77/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.3145 - accuracy: 0.5919
# Epoch 78/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.3046 - accuracy: 0.6045
# Epoch 79/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2949 - accuracy: 0.6032
# Epoch 80/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2856 - accuracy: 0.5999
# Epoch 81/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2765 - accuracy: 0.6005
# Epoch 82/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2676 - accuracy: 0.6111
# Epoch 83/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2592 - accuracy: 0.6118
# Epoch 84/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 1.2511 - accuracy: 0.6091
# Epoch 85/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2431 - accuracy: 0.6151
# Epoch 86/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 1.2348 - accuracy: 0.6144
# Epoch 87/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.2269 - accuracy: 0.6098
# Epoch 88/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.2192 - accuracy: 0.6157
# Epoch 89/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2118 - accuracy: 0.6184
# Epoch 90/1000
# 6/6 [==============================] - ETA: 0s - loss: 1.2735 - accuracy: 0.63 - 0s 8ms/step - loss: 1.2047 - accuracy: 0.6237
# Epoch 91/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1977 - accuracy: 0.6243
# Epoch 92/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1905 - accuracy: 0.6250
# Epoch 93/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1838 - accuracy: 0.6270
# Epoch 94/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1772 - accuracy: 0.6303
# Epoch 95/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1706 - accuracy: 0.6323
# Epoch 96/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1640 - accuracy: 0.6329
# Epoch 97/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1578 - accuracy: 0.6296
# Epoch 98/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1517 - accuracy: 0.6336
# Epoch 99/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1455 - accuracy: 0.6389
# Epoch 100/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1394 - accuracy: 0.6382
# Epoch 101/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1336 - accuracy: 0.6369
# Epoch 102/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 1.1276 - accuracy: 0.6369
# Epoch 103/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1218 - accuracy: 0.6382
# Epoch 104/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1166 - accuracy: 0.6415
# Epoch 105/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1105 - accuracy: 0.6468
# Epoch 106/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1051 - accuracy: 0.6455
# Epoch 107/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0998 - accuracy: 0.6495
# Epoch 108/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0943 - accuracy: 0.6508
# Epoch 109/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0887 - accuracy: 0.6521
# Epoch 110/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0840 - accuracy: 0.6508
# Epoch 111/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0786 - accuracy: 0.6521
# Epoch 112/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0735 - accuracy: 0.6594
# Epoch 113/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0687 - accuracy: 0.6594
# Epoch 114/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0637 - accuracy: 0.6567
# Epoch 115/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0591 - accuracy: 0.6614
# Epoch 116/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0540 - accuracy: 0.6634
# Epoch 117/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0493 - accuracy: 0.6647
# Epoch 118/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0445 - accuracy: 0.6627
# Epoch 119/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0400 - accuracy: 0.6680
# Epoch 120/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0355 - accuracy: 0.6687
# Epoch 121/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 1.0310 - accuracy: 0.6700
# Epoch 122/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0267 - accuracy: 0.6713
# Epoch 123/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0221 - accuracy: 0.6726
# Epoch 124/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0178 - accuracy: 0.6759
# Epoch 125/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0138 - accuracy: 0.6825
# Epoch 126/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 1.0097 - accuracy: 0.6819
# Epoch 127/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0054 - accuracy: 0.6839
# Epoch 128/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0013 - accuracy: 0.6819
# Epoch 129/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9972 - accuracy: 0.6812
# Epoch 130/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9931 - accuracy: 0.6792
# Epoch 131/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9893 - accuracy: 0.6878
# Epoch 132/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9852 - accuracy: 0.6872
# Epoch 133/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9815 - accuracy: 0.6905
# Epoch 134/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9779 - accuracy: 0.6925
# Epoch 135/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9739 - accuracy: 0.6978
# Epoch 136/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9705 - accuracy: 0.6971
# Epoch 137/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9664 - accuracy: 0.6951
# Epoch 138/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9630 - accuracy: 0.6918
# Epoch 139/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9593 - accuracy: 0.6938
# Epoch 140/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9561 - accuracy: 0.6971
# Epoch 141/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9523 - accuracy: 0.6997
# Epoch 142/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9489 - accuracy: 0.7070
# Epoch 143/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9457 - accuracy: 0.7044
# Epoch 144/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9426 - accuracy: 0.6997
# Epoch 145/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9387 - accuracy: 0.7063
# Epoch 146/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9357 - accuracy: 0.7110
# Epoch 147/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9325 - accuracy: 0.7136
# Epoch 148/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9295 - accuracy: 0.7057
# Epoch 149/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9261 - accuracy: 0.7077
# Epoch 150/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9228 - accuracy: 0.7116
# Epoch 151/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9201 - accuracy: 0.7090
# Epoch 152/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9168 - accuracy: 0.7116
# Epoch 153/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9137 - accuracy: 0.7116
# Epoch 154/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9105 - accuracy: 0.7097
# Epoch 155/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9075 - accuracy: 0.7116
# Epoch 156/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9048 - accuracy: 0.7097
# Epoch 157/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9017 - accuracy: 0.7143
# Epoch 158/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8989 - accuracy: 0.7136
# Epoch 159/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8960 - accuracy: 0.7143
# Epoch 160/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8932 - accuracy: 0.7136
# Epoch 161/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8904 - accuracy: 0.7163
# Epoch 162/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8876 - accuracy: 0.7196
# Epoch 163/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8850 - accuracy: 0.7176
# Epoch 164/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8823 - accuracy: 0.7183
# Epoch 165/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8795 - accuracy: 0.7235
# Epoch 166/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8769 - accuracy: 0.7183
# Epoch 167/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8741 - accuracy: 0.7196
# Epoch 168/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8716 - accuracy: 0.7209
# Epoch 169/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8690 - accuracy: 0.7209
# Epoch 170/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8664 - accuracy: 0.7235
# Epoch 171/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8639 - accuracy: 0.7229
# Epoch 172/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8611 - accuracy: 0.7262
# Epoch 173/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8585 - accuracy: 0.7282
# Epoch 174/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8561 - accuracy: 0.7275
# Epoch 175/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8537 - accuracy: 0.7262
# Epoch 176/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8513 - accuracy: 0.7295
# Epoch 177/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8487 - accuracy: 0.7315
# Epoch 178/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8463 - accuracy: 0.7295
# Epoch 179/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8442 - accuracy: 0.7288
# Epoch 180/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8418 - accuracy: 0.7288
# Epoch 181/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8392 - accuracy: 0.7302
# Epoch 182/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8368 - accuracy: 0.7354
# Epoch 183/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8343 - accuracy: 0.7394
# Epoch 184/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8322 - accuracy: 0.7407
# Epoch 185/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8299 - accuracy: 0.7381
# Epoch 186/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8277 - accuracy: 0.7434
# Epoch 187/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8255 - accuracy: 0.7454
# Epoch 188/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8231 - accuracy: 0.7447
# Epoch 189/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8206 - accuracy: 0.7467
# Epoch 190/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8188 - accuracy: 0.7460
# Epoch 191/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.8164 - accuracy: 0.7487
# Epoch 192/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8144 - accuracy: 0.7526
# Epoch 193/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8120 - accuracy: 0.7460
# Epoch 194/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8097 - accuracy: 0.7513
# Epoch 195/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.8075 - accuracy: 0.7493
# Epoch 196/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8052 - accuracy: 0.7493
# Epoch 197/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8036 - accuracy: 0.7487
# Epoch 198/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8010 - accuracy: 0.7520
# Epoch 199/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7993 - accuracy: 0.7540
# Epoch 200/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7969 - accuracy: 0.7526
# Epoch 201/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7946 - accuracy: 0.7566
# Epoch 202/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7925 - accuracy: 0.7566
# Epoch 203/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7907 - accuracy: 0.7540
# Epoch 204/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7882 - accuracy: 0.7553
# Epoch 205/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7864 - accuracy: 0.7573
# Epoch 206/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7845 - accuracy: 0.7586
# Epoch 207/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7823 - accuracy: 0.7586
# Epoch 208/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7804 - accuracy: 0.7606
# Epoch 209/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7783 - accuracy: 0.7599
# Epoch 210/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7761 - accuracy: 0.7586
# Epoch 211/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7744 - accuracy: 0.7626
# Epoch 212/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7719 - accuracy: 0.7599
# Epoch 213/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7699 - accuracy: 0.7586
# Epoch 214/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7680 - accuracy: 0.7612
# Epoch 215/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7660 - accuracy: 0.7619
# Epoch 216/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7638 - accuracy: 0.7632
# Epoch 217/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7618 - accuracy: 0.7626
# Epoch 218/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7600 - accuracy: 0.7659
# Epoch 219/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7579 - accuracy: 0.7652
# Epoch 220/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7558 - accuracy: 0.7652
# Epoch 221/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.7255 - accuracy: 0.78 - 0s 8ms/step - loss: 0.7537 - accuracy: 0.7619
# Epoch 222/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7520 - accuracy: 0.7685
# Epoch 223/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7506 - accuracy: 0.7632
# Epoch 224/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7480 - accuracy: 0.7665
# Epoch 225/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7459 - accuracy: 0.7725
# Epoch 226/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7443 - accuracy: 0.7745
# Epoch 227/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7424 - accuracy: 0.7731
# Epoch 228/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7401 - accuracy: 0.7725
# Epoch 229/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7383 - accuracy: 0.7751
# Epoch 230/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7367 - accuracy: 0.7731
# Epoch 231/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7346 - accuracy: 0.7758
# Epoch 232/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7325 - accuracy: 0.7758
# Epoch 233/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7306 - accuracy: 0.7765
# Epoch 234/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7287 - accuracy: 0.7791
# Epoch 235/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7267 - accuracy: 0.7791
# Epoch 236/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7245 - accuracy: 0.7778
# Epoch 237/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7226 - accuracy: 0.7771
# Epoch 238/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7206 - accuracy: 0.7791
# Epoch 239/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7191 - accuracy: 0.7851
# Epoch 240/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7170 - accuracy: 0.7804
# Epoch 241/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7147 - accuracy: 0.7811
# Epoch 242/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7130 - accuracy: 0.7817
# Epoch 243/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7107 - accuracy: 0.7824
# Epoch 244/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7089 - accuracy: 0.7824
# Epoch 245/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7070 - accuracy: 0.7857
# Epoch 246/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7049 - accuracy: 0.7857
# Epoch 247/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7034 - accuracy: 0.7831
# Epoch 248/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7017 - accuracy: 0.7844
# Epoch 249/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6999 - accuracy: 0.7923
# Epoch 250/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6973 - accuracy: 0.7917
# Epoch 251/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6955 - accuracy: 0.7851
# Epoch 252/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6934 - accuracy: 0.7903
# Epoch 253/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6915 - accuracy: 0.7917
# Epoch 254/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6893 - accuracy: 0.7963
# Epoch 255/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6877 - accuracy: 0.7897
# Epoch 256/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6857 - accuracy: 0.7923
# Epoch 257/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6835 - accuracy: 0.7943
# Epoch 258/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6815 - accuracy: 0.7937
# Epoch 259/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6796 - accuracy: 0.7937
# Epoch 260/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6776 - accuracy: 0.7950
# Epoch 261/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6757 - accuracy: 0.7950
# Epoch 262/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6739 - accuracy: 0.7970
# Epoch 263/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6717 - accuracy: 0.7983
# Epoch 264/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6699 - accuracy: 0.7937
# Epoch 265/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6677 - accuracy: 0.7950
# Epoch 266/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6659 - accuracy: 0.7963
# Epoch 267/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6637 - accuracy: 0.7976
# Epoch 268/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6617 - accuracy: 0.7963
# Epoch 269/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6598 - accuracy: 0.7976
# Epoch 270/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6577 - accuracy: 0.8009
# Epoch 271/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6558 - accuracy: 0.7976
# Epoch 272/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6538 - accuracy: 0.8003
# Epoch 273/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6521 - accuracy: 0.7996
# Epoch 274/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6499 - accuracy: 0.8016
# Epoch 275/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6479 - accuracy: 0.8016
# Epoch 276/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6458 - accuracy: 0.8029
# Epoch 277/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6438 - accuracy: 0.8029
# Epoch 278/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6420 - accuracy: 0.8049
# Epoch 279/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6403 - accuracy: 0.8036
# Epoch 280/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6378 - accuracy: 0.8049
# Epoch 281/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6360 - accuracy: 0.8036
# Epoch 282/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6342 - accuracy: 0.8056
# Epoch 283/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6319 - accuracy: 0.8069
# Epoch 284/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6303 - accuracy: 0.8082
# Epoch 285/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6280 - accuracy: 0.8056
# Epoch 286/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6260 - accuracy: 0.8082
# Epoch 287/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6239 - accuracy: 0.8102
# Epoch 288/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6223 - accuracy: 0.8095
# Epoch 289/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6201 - accuracy: 0.8095
# Epoch 290/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6183 - accuracy: 0.8108
# Epoch 291/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6161 - accuracy: 0.8135
# Epoch 292/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6143 - accuracy: 0.8122
# Epoch 293/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6121 - accuracy: 0.8142
# Epoch 294/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6103 - accuracy: 0.8128
# Epoch 295/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6086 - accuracy: 0.8168
# Epoch 296/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6060 - accuracy: 0.8168
# Epoch 297/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6044 - accuracy: 0.8161
# Epoch 298/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6021 - accuracy: 0.8135
# Epoch 299/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6002 - accuracy: 0.8168
# Epoch 300/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5982 - accuracy: 0.8194
# Epoch 301/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5960 - accuracy: 0.8161
# Epoch 302/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5945 - accuracy: 0.8188
# Epoch 303/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5929 - accuracy: 0.8188
# Epoch 304/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5900 - accuracy: 0.8208
# Epoch 305/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5873 - accuracy: 0.8208
# Epoch 306/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5856 - accuracy: 0.8228
# Epoch 307/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5827 - accuracy: 0.8228
# Epoch 308/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5805 - accuracy: 0.8228
# Epoch 309/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5787 - accuracy: 0.8201
# Epoch 310/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5769 - accuracy: 0.8221
# Epoch 311/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5744 - accuracy: 0.8228
# Epoch 312/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5727 - accuracy: 0.8214
# Epoch 313/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5709 - accuracy: 0.8241
# Epoch 314/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5687 - accuracy: 0.8241
# Epoch 315/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5667 - accuracy: 0.8274
# Epoch 316/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5647 - accuracy: 0.8274
# Epoch 317/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5628 - accuracy: 0.8247
# Epoch 318/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5612 - accuracy: 0.8254
# Epoch 319/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5586 - accuracy: 0.8267
# Epoch 320/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5579 - accuracy: 0.8234
# Epoch 321/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5556 - accuracy: 0.8261
# Epoch 322/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5535 - accuracy: 0.8287
# Epoch 323/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5517 - accuracy: 0.8274
# Epoch 324/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5499 - accuracy: 0.8261
# Epoch 325/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5477 - accuracy: 0.8287
# Epoch 326/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5460 - accuracy: 0.8294
# Epoch 327/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5439 - accuracy: 0.8300
# Epoch 328/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5424 - accuracy: 0.8294
# Epoch 329/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5405 - accuracy: 0.8307
# Epoch 330/1000
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5384 - accuracy: 0.8307
# Epoch 331/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5367 - accuracy: 0.8333
# Epoch 332/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5349 - accuracy: 0.8313
# Epoch 333/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5336 - accuracy: 0.8294
# Epoch 334/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5316 - accuracy: 0.8307
# Epoch 335/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5297 - accuracy: 0.8353
# Epoch 336/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5278 - accuracy: 0.8347
# Epoch 337/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5262 - accuracy: 0.8340
# Epoch 338/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5244 - accuracy: 0.8333
# Epoch 339/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5228 - accuracy: 0.8320
# Epoch 340/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5211 - accuracy: 0.8340
# Epoch 341/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.5193 - accuracy: 0.83 - 0s 13ms/step - loss: 0.5193 - accuracy: 0.8366
# Epoch 342/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5189 - accuracy: 0.8360
# Epoch 343/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5170 - accuracy: 0.8360
# Epoch 344/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5146 - accuracy: 0.8360
# Epoch 345/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5131 - accuracy: 0.8399
# Epoch 346/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5114 - accuracy: 0.8406
# Epoch 347/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5092 - accuracy: 0.8413
# Epoch 348/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5076 - accuracy: 0.8406
# Epoch 349/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5068 - accuracy: 0.8452
# Epoch 350/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5044 - accuracy: 0.8446
# Epoch 351/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5030 - accuracy: 0.8439
# Epoch 352/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5010 - accuracy: 0.8413
# Epoch 353/1000
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5000 - accuracy: 0.8446 0s - loss: 0.4950 - accuracy: 0.84
# Epoch 354/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4982 - accuracy: 0.8485
# Epoch 355/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4964 - accuracy: 0.8459
# Epoch 356/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4948 - accuracy: 0.8466
# Epoch 357/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4932 - accuracy: 0.8466
# Epoch 358/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4916 - accuracy: 0.8466
# Epoch 359/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4899 - accuracy: 0.8466
# Epoch 360/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4884 - accuracy: 0.8479
# Epoch 361/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4873 - accuracy: 0.8492
# Epoch 362/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4851 - accuracy: 0.8492
# Epoch 363/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4839 - accuracy: 0.8499
# Epoch 364/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4824 - accuracy: 0.8485
# Epoch 365/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4806 - accuracy: 0.8472
# Epoch 366/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4790 - accuracy: 0.8479
# Epoch 367/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4777 - accuracy: 0.8505
# Epoch 368/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4764 - accuracy: 0.8499
# Epoch 369/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4747 - accuracy: 0.8492
# Epoch 370/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4733 - accuracy: 0.8525
# Epoch 371/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4721 - accuracy: 0.8525
# Epoch 372/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4700 - accuracy: 0.8492
# Epoch 373/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4687 - accuracy: 0.8505
# Epoch 374/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4671 - accuracy: 0.8499
# Epoch 375/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4657 - accuracy: 0.8512
# Epoch 376/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.4076 - accuracy: 0.86 - 0s 7ms/step - loss: 0.4643 - accuracy: 0.8519
# Epoch 377/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4628 - accuracy: 0.8545
# Epoch 378/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4616 - accuracy: 0.8512
# Epoch 379/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4598 - accuracy: 0.8485
# Epoch 380/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4585 - accuracy: 0.8538
# Epoch 381/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4568 - accuracy: 0.8532
# Epoch 382/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4557 - accuracy: 0.8525
# Epoch 383/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4542 - accuracy: 0.8538
# Epoch 384/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4527 - accuracy: 0.8545
# Epoch 385/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4516 - accuracy: 0.8552
# Epoch 386/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4500 - accuracy: 0.8565
# Epoch 387/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4487 - accuracy: 0.8558
# Epoch 388/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4477 - accuracy: 0.8545
# Epoch 389/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4465 - accuracy: 0.8525
# Epoch 390/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4448 - accuracy: 0.8585
# Epoch 391/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4436 - accuracy: 0.8578
# Epoch 392/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4422 - accuracy: 0.8552
# Epoch 393/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4407 - accuracy: 0.8591
# Epoch 394/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4395 - accuracy: 0.8598
# Epoch 395/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4381 - accuracy: 0.8591
# Epoch 396/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4372 - accuracy: 0.8604
# Epoch 397/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4357 - accuracy: 0.8598
# Epoch 398/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4356 - accuracy: 0.8604
# Epoch 399/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4335 - accuracy: 0.8611
# Epoch 400/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4324 - accuracy: 0.8618
# Epoch 401/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4312 - accuracy: 0.8591
# Epoch 402/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4296 - accuracy: 0.8611
# Epoch 403/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4286 - accuracy: 0.8631
# Epoch 404/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4274 - accuracy: 0.8624
# Epoch 405/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4261 - accuracy: 0.8598
# Epoch 406/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4250 - accuracy: 0.8611
# Epoch 407/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4239 - accuracy: 0.8638
# Epoch 408/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4231 - accuracy: 0.8638
# Epoch 409/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4215 - accuracy: 0.8638
# Epoch 410/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.3894 - accuracy: 0.87 - 0s 8ms/step - loss: 0.4203 - accuracy: 0.8644
# Epoch 411/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4191 - accuracy: 0.8657
# Epoch 412/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4180 - accuracy: 0.8671
# Epoch 413/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4169 - accuracy: 0.8671
# Epoch 414/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4157 - accuracy: 0.8677
# Epoch 415/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4147 - accuracy: 0.8690
# Epoch 416/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4135 - accuracy: 0.8671
# Epoch 417/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4126 - accuracy: 0.8664
# Epoch 418/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4116 - accuracy: 0.8697
# Epoch 419/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4106 - accuracy: 0.8704
# Epoch 420/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4108 - accuracy: 0.8631
# Epoch 421/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4086 - accuracy: 0.8651
# Epoch 422/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4074 - accuracy: 0.8710
# Epoch 423/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4062 - accuracy: 0.8704
# Epoch 424/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4054 - accuracy: 0.8664
# Epoch 425/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4039 - accuracy: 0.8690
# Epoch 426/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4033 - accuracy: 0.8697
# Epoch 427/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4020 - accuracy: 0.8710
# Epoch 428/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4016 - accuracy: 0.8704
# Epoch 429/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4004 - accuracy: 0.8710
# Epoch 430/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3992 - accuracy: 0.8730
# Epoch 431/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3979 - accuracy: 0.8704
# Epoch 432/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3972 - accuracy: 0.8690
# Epoch 433/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3962 - accuracy: 0.8717
# Epoch 434/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3949 - accuracy: 0.8743
# Epoch 435/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3940 - accuracy: 0.8710
# Epoch 436/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3931 - accuracy: 0.8717
# Epoch 437/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3925 - accuracy: 0.8743
# Epoch 438/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3913 - accuracy: 0.8704
# Epoch 439/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3903 - accuracy: 0.8704
# Epoch 440/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3893 - accuracy: 0.8717
# Epoch 441/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3883 - accuracy: 0.8730
# Epoch 442/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3879 - accuracy: 0.8743
# Epoch 443/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3865 - accuracy: 0.8724
# Epoch 444/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3860 - accuracy: 0.8750
# Epoch 445/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3847 - accuracy: 0.8757
# Epoch 446/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3838 - accuracy: 0.8763
# Epoch 447/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3829 - accuracy: 0.8750
# Epoch 448/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3818 - accuracy: 0.8757
# Epoch 449/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3817 - accuracy: 0.8750
# Epoch 450/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3803 - accuracy: 0.8757
# Epoch 451/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3793 - accuracy: 0.8783
# Epoch 452/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3783 - accuracy: 0.8770
# Epoch 453/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3777 - accuracy: 0.8750
# Epoch 454/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3768 - accuracy: 0.8763
# Epoch 455/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3758 - accuracy: 0.8810
# Epoch 456/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3751 - accuracy: 0.8776
# Epoch 457/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3740 - accuracy: 0.8783
# Epoch 458/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3733 - accuracy: 0.8783
# Epoch 459/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3722 - accuracy: 0.8803
# Epoch 460/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3716 - accuracy: 0.8810
# Epoch 461/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.90 - 0s 8ms/step - loss: 0.3708 - accuracy: 0.8810
# Epoch 462/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.3885 - accuracy: 0.89 - 0s 8ms/step - loss: 0.3701 - accuracy: 0.8816
# Epoch 463/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3689 - accuracy: 0.8810
# Epoch 464/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3681 - accuracy: 0.8796
# Epoch 465/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3675 - accuracy: 0.8823
# Epoch 466/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.90 - 0s 8ms/step - loss: 0.3667 - accuracy: 0.8803
# Epoch 467/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3657 - accuracy: 0.8810
# Epoch 468/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.3246 - accuracy: 0.90 - 0s 7ms/step - loss: 0.3651 - accuracy: 0.8803
# Epoch 469/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3640 - accuracy: 0.8803
# Epoch 470/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3633 - accuracy: 0.8816
# Epoch 471/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3626 - accuracy: 0.8810
# Epoch 472/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3618 - accuracy: 0.8816
# Epoch 473/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3608 - accuracy: 0.8816
# ...
# Epoch 844/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1711 - accuracy: 0.9431
# Epoch 845/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1699 - accuracy: 0.9464
# Epoch 846/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1698 - accuracy: 0.9471
# Epoch 847/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1691 - accuracy: 0.9484
# Epoch 848/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1691 - accuracy: 0.9444
# Epoch 849/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1683 - accuracy: 0.9478
# Epoch 850/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1681 - accuracy: 0.9504
# Epoch 851/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1679 - accuracy: 0.9484
# Epoch 852/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1677 - accuracy: 0.9451
# Epoch 853/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1669 - accuracy: 0.9458
# Epoch 854/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1670 - accuracy: 0.9478
# Epoch 855/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.96 - 0s 8ms/step - loss: 0.1667 - accuracy: 0.9464
# Epoch 856/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1662 - accuracy: 0.9524
# Epoch 857/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1656 - accuracy: 0.9497
# Epoch 858/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1650 - accuracy: 0.9497
# Epoch 859/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1646 - accuracy: 0.9471
# Epoch 860/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1643 - accuracy: 0.9471
# Epoch 861/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1638 - accuracy: 0.9511
# Epoch 862/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1636 - accuracy: 0.9504
# Epoch 863/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1632 - accuracy: 0.9491
# Epoch 864/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1629 - accuracy: 0.9504
# Epoch 865/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1624 - accuracy: 0.9504
# Epoch 866/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1621 - accuracy: 0.9511
# Epoch 867/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1618 - accuracy: 0.9511
# Epoch 868/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1613 - accuracy: 0.9524
# Epoch 869/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1610 - accuracy: 0.9517
# Epoch 870/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1606 - accuracy: 0.9504
# Epoch 871/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1603 - accuracy: 0.9517
# Epoch 872/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1605 - accuracy: 0.9511
# Epoch 873/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.95 - 0s 7ms/step - loss: 0.1599 - accuracy: 0.9511
# Epoch 874/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1593 - accuracy: 0.9504
# Epoch 875/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1589 - accuracy: 0.9530
# Epoch 876/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1586 - accuracy: 0.9524
# Epoch 877/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1583 - accuracy: 0.9517
# Epoch 878/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1577 - accuracy: 0.9517
# Epoch 879/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1574 - accuracy: 0.9517
# Epoch 880/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1571 - accuracy: 0.9524
# Epoch 881/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1567 - accuracy: 0.9517
# Epoch 882/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1567 - accuracy: 0.9517
# Epoch 883/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1560 - accuracy: 0.9524
# Epoch 884/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1558 - accuracy: 0.9517
# Epoch 885/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1558 - accuracy: 0.9517
# Epoch 886/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1550 - accuracy: 0.9524
# Epoch 887/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1547 - accuracy: 0.9537
# Epoch 888/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.96 - 0s 8ms/step - loss: 0.1545 - accuracy: 0.9530
# Epoch 889/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1539 - accuracy: 0.9524
# Epoch 890/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1539 - accuracy: 0.9517
# Epoch 891/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1536 - accuracy: 0.9530
# Epoch 892/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1528 - accuracy: 0.9530
# Epoch 893/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1527 - accuracy: 0.9537
# Epoch 894/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1527 - accuracy: 0.9524
# Epoch 895/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1524 - accuracy: 0.9530
# Epoch 896/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1515 - accuracy: 0.9537
# Epoch 897/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1514 - accuracy: 0.9524
# Epoch 898/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1511 - accuracy: 0.9524
# Epoch 899/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1505 - accuracy: 0.9530
# Epoch 900/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1501 - accuracy: 0.9530
# Epoch 901/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1497 - accuracy: 0.9537
# Epoch 902/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1495 - accuracy: 0.9563
# Epoch 903/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1495 - accuracy: 0.9544
# Epoch 904/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1491 - accuracy: 0.9557
# Epoch 905/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1487 - accuracy: 0.9530
# Epoch 906/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1480 - accuracy: 0.9557
# Epoch 907/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1477 - accuracy: 0.9570
# Epoch 908/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1476 - accuracy: 0.9563
# Epoch 909/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1473 - accuracy: 0.9557
# Epoch 910/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1468 - accuracy: 0.9577
# Epoch 911/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1466 - accuracy: 0.9557
# Epoch 912/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1461 - accuracy: 0.9570
# Epoch 913/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1458 - accuracy: 0.9577
# Epoch 914/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1455 - accuracy: 0.9570
# Epoch 915/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1453 - accuracy: 0.9563
# Epoch 916/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1455 - accuracy: 0.9577
# Epoch 917/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1449 - accuracy: 0.9577
# Epoch 918/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1444 - accuracy: 0.9570
# Epoch 919/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1439 - accuracy: 0.9590
# Epoch 920/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1438 - accuracy: 0.9590
# Epoch 921/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1434 - accuracy: 0.9570
# Epoch 922/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1430 - accuracy: 0.9603
# Epoch 923/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1428 - accuracy: 0.9603
# Epoch 924/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1428 - accuracy: 0.9590
# Epoch 925/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1421 - accuracy: 0.9597
# Epoch 926/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1417 - accuracy: 0.9597
# Epoch 927/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1413 - accuracy: 0.9583
# Epoch 928/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1411 - accuracy: 0.9583
# Epoch 929/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1407 - accuracy: 0.9603
# Epoch 930/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1404 - accuracy: 0.9590
# Epoch 931/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1406 - accuracy: 0.9590
# Epoch 932/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1396 - accuracy: 0.9603
# Epoch 933/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1395 - accuracy: 0.9616
# Epoch 934/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1394 - accuracy: 0.9616
# Epoch 935/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1391 - accuracy: 0.9583
# Epoch 936/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1390 - accuracy: 0.9590
# Epoch 937/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1387 - accuracy: 0.9603
# Epoch 938/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1381 - accuracy: 0.9610
# Epoch 939/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1378 - accuracy: 0.9603
# Epoch 940/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1375 - accuracy: 0.9590
# Epoch 941/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1369 - accuracy: 0.9623
# Epoch 942/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1368 - accuracy: 0.9610
# Epoch 943/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1363 - accuracy: 0.9616
# Epoch 944/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1360 - accuracy: 0.9616
# Epoch 945/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1363 - accuracy: 0.9610
# Epoch 946/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1357 - accuracy: 0.9616
# Epoch 947/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1359 - accuracy: 0.9603
# Epoch 948/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1351 - accuracy: 0.9616
# Epoch 949/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1349 - accuracy: 0.9603
# Epoch 950/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1348 - accuracy: 0.9603
# Epoch 951/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1344 - accuracy: 0.9616
# Epoch 952/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1339 - accuracy: 0.9616
# Epoch 953/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1335 - accuracy: 0.9616
# Epoch 954/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1334 - accuracy: 0.9610
# Epoch 955/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1329 - accuracy: 0.9630
# Epoch 956/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1325 - accuracy: 0.9636
# Epoch 957/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1325 - accuracy: 0.9630
# Epoch 958/1000
# 6/6 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.96 - 0s 7ms/step - loss: 0.1320 - accuracy: 0.9636
# Epoch 959/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1320 - accuracy: 0.9616
# Epoch 960/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1318 - accuracy: 0.9636
# Epoch 961/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1313 - accuracy: 0.9630
# Epoch 962/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1309 - accuracy: 0.9616
# Epoch 963/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1310 - accuracy: 0.9616
# Epoch 964/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1305 - accuracy: 0.9636
# Epoch 965/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1301 - accuracy: 0.9630
# Epoch 966/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1298 - accuracy: 0.9623
# Epoch 967/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1299 - accuracy: 0.9630
# Epoch 968/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1292 - accuracy: 0.9643
# Epoch 969/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1295 - accuracy: 0.9623
# Epoch 970/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1292 - accuracy: 0.9643
# Epoch 971/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1283 - accuracy: 0.9643
# Epoch 972/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1285 - accuracy: 0.9623
# Epoch 973/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1279 - accuracy: 0.9623
# Epoch 974/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1277 - accuracy: 0.9636
# Epoch 975/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1272 - accuracy: 0.9643
# Epoch 976/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1270 - accuracy: 0.9643
# Epoch 977/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1269 - accuracy: 0.9636
# Epoch 978/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1265 - accuracy: 0.9649
# Epoch 979/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1267 - accuracy: 0.9623
# Epoch 980/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1260 - accuracy: 0.9636
# Epoch 981/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1257 - accuracy: 0.9636
# Epoch 982/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1255 - accuracy: 0.9649
# Epoch 983/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1257 - accuracy: 0.9643
# Epoch 984/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1251 - accuracy: 0.9656
# Epoch 985/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1248 - accuracy: 0.9623
# Epoch 986/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1245 - accuracy: 0.9643
# Epoch 987/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1245 - accuracy: 0.9656
# Epoch 988/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1239 - accuracy: 0.9656
# Epoch 989/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1237 - accuracy: 0.9636
# Epoch 990/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1238 - accuracy: 0.9663
# Epoch 991/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1232 - accuracy: 0.9656
# Epoch 992/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1229 - accuracy: 0.9643
# Epoch 993/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1228 - accuracy: 0.9643
# Epoch 994/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1225 - accuracy: 0.9649
# Epoch 995/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1224 - accuracy: 0.9663
# Epoch 996/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1222 - accuracy: 0.9656
# Epoch 997/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1217 - accuracy: 0.9656
# Epoch 998/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1213 - accuracy: 0.9656
# Epoch 999/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1213 - accuracy: 0.9643
# Epoch 1000/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1206 - accuracy: 0.9663
# Accuracy: 91.67 %
# Precision: 92.28 %
# Recall: 91.67 %
# f1 score: 91.79 %

# %% [markdown]
# - - -
# # 6. Performance Results:
# After training the classifier with the training data, it’s time to test its accuracy against testing data (i.e. data that is unseen or new for the classification algorithm). The accuracy is reported as the percentage of the number of instances that were correctly classified to the total number of instances.

# %% [markdown]
# Computing the following metrics
#   1. **Accuracy.**
#   2. **Precision.**
#   3. **Recall.**
#   4. **f1 score**

# %%
#Accuracies
print('----------------------------------------------------------------------')
print("The mean of each classifier's accuracies:")
print('----SVM--------------------KNN--------------RF--------------NN--------')

print(svm_real_score[0]*100,knn_real_score[0]*100,rf_real_score[0]*100,nn_real_score[0]*100)

print('----------------------------------------------------------------------')
#Precision
print("Precision:")
print('----SVM--------------------KNN--------------RF--------------NN--------')

print(svm_real_score[1]*100,knn_real_score[1]*100,rf_real_score[1]*100,nn_real_score[1]*100)

print('----------------------------------------------------------------------')
#Recall
print("Recall:")
print('----SVM--------------------KNN--------------RF--------------NN--------')

print(svm_real_score[2]*100,knn_real_score[2]*100,rf_real_score[2]*100,nn_real_score[2]*100)

print('----------------------------------------------------------------------')
#F1-score
print("F1-score:")
print('----SVM--------------------KNN--------------RF--------------NN--------')

print(svm_real_score[3]*100,knn_real_score[3]*100,rf_real_score[3]*100,nn_real_score[3]*100)
# Out:
# ----------------------------------------------------------------
# The mean of each classifier's accuracies:
# ----SVM--------------------KNN--------------RF--------------NN--------
# 98.63095238095238 91.19047619047619 98.98809523809524 95.59523809523809
# ----------------------------------------------------------------
# Precision:
# ----SVM--------------------KNN--------------RF--------------NN--------
# 98.70547078812919 91.46848577254522 99.04132878708334 95.80681228869933
# ----------------------------------------------------------------
# Recall:
# ----SVM--------------------KNN--------------RF--------------NN--------
# 98.63095238095238 91.19047619047619 98.98809523809524 95.59523809523809
# ----------------------------------------------------------------
# F1-score:
# ----SVM--------------------KNN--------------RF--------------NN--------
# 98.63250091706055 91.10812219089937 98.98768116688774 95.60862645777627
